# %% [markdown]
# # Day 4
#
# ## Tokenizing with code

# %%
pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.13.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting regex (from tiktoken)
#   Downloading regex-2026.5.9-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests->tiktoken) (2025.10.5)
# Downloading tiktoken-0.13.0-cp313-cp313-macosx_11_0_arm64.whl (982 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.0/983.0 kB 3.4 MB/s  0:00:00 eta 0:00:01
# Downloading regex-2026.5.9-cp313-cp313-macosx_11_0_arm64.whl (289 kB)
# Installing collected packages: regex, tiktoken
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [tiktoken]
# Successfully installed regex-2026.5.9 tiktoken-0.13.0
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")

tokens = encoding.encode("Hi my name is Sameer and I love watching WWE, playing Cricket and I am a big Western Philosophy fan.")

print(tokens)
# Out:
# [12194, 922, 1308, 382, 38569, 259, 326, 357, 3047, 14705, 64277, 11, 8252, 79366, 326, 357, 939, 261, 3464, 16766, 77548, 6831, 13]

# %%
tokens

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 922 =  my
# 1308 =  name
# 382 =  is
# 38569 =  Same
# 259 = er
# 326 =  and
# 357 =  I
# 3047 =  love
# 14705 =  watching
# 64277 =  WWE
# 11 = ,
# 8252 =  playing
# 79366 =  Cricket
# 326 =  and
# 357 =  I
# 939 =  am
# 261 =  a
# 3464 =  big
# 16766 =  Western
# 77548 =  Philosophy
# 6831 =  fan
# 13 = .

# %%
encoding.decode([326])
# Out:
# ' and'

# %% [markdown]
# # And another topic!
#
# ### The Illusion of "memory"
#
# Many of you will know this already. But for those that don't -- this might be an "AHA" moment!

# %%
# import os
# from dotenv import load_dotenv

# load_dotenv(override=True)
# api_key = os.getenv('OPENAI_API_KEY')

# if not api_key:
#     print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
# elif not api_key.startswith("sk-proj-"):
#     print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
# else:
#     print("API key found and looks good so far!")


### GEMINI


import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('GEMINI_API_KEY')

if not api_key:
    print("No Gemini API key was found - please check your .env file!")
elif not api_key.startswith("AQ."):
    print("An API key was found, but it doesn't look like a valid Gemini key (should start with AQ.)!")
else:
    print("Gemini API key found and looks good so far!")
# Out:
# Gemini API key found and looks good so far!

# %% [markdown]
# ### You should be very comfortable with what the next cell is doing!
#
# _I'm creating a new instance of the OpenAI Python Client library, a lightweight wrapper around making HTTP calls to an endpoint for calling the GPT LLM, or other LLM providers_

# %%
from openai import OpenAI

openai = OpenAI()

# %% [markdown]
# ### A message to OpenAI is a list of dicts

# %%
# messages = [
#     {"role": "system", "content": "You are a helpful assistant"},
#     {"role": "user", "content": "Hi! I'm Sameer Shahzad!"}
#     ]

# %%
pip install google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-2.8.0-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from google-genai) (4.13.0)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Downloading google_auth-2.53.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from google-genai) (2.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from google-genai) (2.32.5)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<17.0,>=13.0.0 (from google-genai)
#   Downloading websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: cryptography>=38.0.3 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (46.0.3)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.23)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai)
#   Using cached pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading google_genai-2.8.0-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.5/832.5 kB 2.0 MB/s  0:00:00 eta 0:00:01
# Downloading google_auth-2.53.0-py3-none-any.whl (246 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl (175 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Installing collected packages: websockets, tenacity, pyasn1, pyasn1-modules, google-auth, google-genai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [google-genai] [google-genai]s]
# Successfully installed google-auth-2.53.0 google-genai-2.8.0 pyasn1-0.6.3 pyasn1-modules-0.4.2 tenacity-9.1.4 websockets-16.0
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
# response.choices[0].message.content

### GEMINI

from google import genai
from google.genai import types

client = genai.Client()

config = types.GenerateContentConfig(
    system_instruction="You are a helpful assistant"
)

messages = ["Hi! I'm Sameer Shahzad!"]

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=messages,
    config=config
)

print(response.text)
# Out:
# Hi Sameer Shahzad! It's nice to meet you. How can I help you today?

# %% [markdown]
# ### OK let's now ask a follow-up question

# %%
# messages = [
#     {"role": "system", "content": "You are a helpful assistant"},
#     {"role": "user", "content": "What's my name?"}
#     ]

# %%
# response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
# response.choices[0].message.content



### GEMINI



from google import genai
from google.genai import types

client = genai.Client()

config = types.GenerateContentConfig(
    system_instruction="You are a helpful assistant"
)

messages = ["What's my name?"]

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=messages,
    config=config
)

print(response.text)
# Out:
# I don't know your name. As an AI, I don't have access to personal information about you unless you choose to tell me!

# %% [markdown]
# ### Wait, wha??
#
# We just told you!
#
# What's going on??
#
# Here's the thing: every call to an LLM is completely STATELESS. It's a totally new call, every single time. As AI engineers, it's OUR JOB to devise techniques to give the impression that the LLM has a "memory".

# %%
# messages = [
#     {"role": "system", "content": "You are a helpful assistant"},
#     {"role": "user", "content": "Hi! I'm Ed!"},
#     {"role": "assistant", "content": "Hi Ed! How can I assist you today?"},
#     {"role": "user", "content": "What's my name?"}
#     ]

# %%
# response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
# response.choices[0].message.content




### GEMINI



from google import genai
from google.genai import types

client = genai.Client()

config = types.GenerateContentConfig(
    system_instruction="You are a helpful assistant"
)

messages = [
    types.Content(
        role="user",
        parts=[types.Part.from_text(text="Hi! I'm Sameer Shahzad!")]
    ),
    types.Content(
        role="model",
        parts=[types.Part.from_text(text="Hi Sameer! How can I assist you today?")]
    ),
    types.Content(
        role="user",
        parts=[types.Part.from_text(text="What's my name?")]
    )
]

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=messages,
    config=config
)

print(response.text)
# Out:
# Your name is Sameer Shahzad!

# %% [markdown]
# ## To recap
#
# With apologies if this is obvious to you - but it's still good to reinforce:
#
# 1. Every call to an LLM is stateless
# 2. We pass in the entire conversation so far in the input prompt, every time
# 3. This gives the illusion that the LLM has memory - it apparently keeps the context of the conversation
# 4. But this is a trick; it's a by-product of providing the entire conversation, every time
# 5. An LLM just predicts the most likely next tokens in the sequence; if that sequence contains "My name is Ed" and later "What's my name?" then it will predict.. Ed!
#
# The ChatGPT product uses exactly this trick - every time you send a message, it's the entire conversation that gets passed in.
#
# "Does that mean we have to pay extra each time for all the conversation so far"
#
# For sure it does. And that's what we WANT. We want the LLM to predict the next tokens in the sequence, looking back on the entire conversation. We want that compute to happen, so we need to pay the electricity bill for it!
